# %% [markdown]
# <a href="https://colab.research.google.com/github/Nanghomnoonaye/CGM-Telemonitoring/blob/main/world_bank_science_technology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World Bank Science and Technology Data Analysis

# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Hom')
# Out:
# Hom

# %%
print(5)
print(5.5)
# Out:
# 5
# 5.5

# %%
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# ## Importing the Data

# %%
st_data_2018 = pd.read_csv("/content/science_tech_2018.csv")
st_data_2018.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           0.049514
# 2         Algeria                                                NaN
# 3  American Samoa                                                NaN
# 4         Andorra                                          28.460560
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                               591717.0                         3713.0
# 2                                    NaN                         9490.0
# 3                                    NaN                            NaN
# 4                             33913480.0                         1180.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
st_data_2018.shape
# Out:
# (219, 10)

# %%
st_data_2018.size
# Out:
# 2190

# %%
st_data_2018.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
st_data_2009 = pd.read_csv("/content/science_tech_2009.csv")
st_data_2009.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           1.328024
# 2         Algeria                                           0.653887
# 3  American Samoa                                                NaN
# 4         Andorra                                          12.192161
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                             10128935.0                         3456.0
# 2                              4616076.0                         5345.0
# 3                                    NaN                            NaN
# 4                             10402350.0                          785.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
st_data_2009.shape
# Out:
# (219, 10)

# %%
st_data_2009.size
# Out:
# 2190

# %%
st_data_2009.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Missing Data

# %%
st_data_2018.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     87
# High-technology exports (current US$)                   88
# Trademark applications, total                           86
# Trademark applications, direct resident                 91
# Trademark applications, direct nonresident              90
# Patent applications, residents                         101
# Patent applications, nonresidents                      100
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        146
# dtype: int64

# %%
st_data_2018.clean = st_data_2018.dropna()
st_data_2018.clean.shape
# Out:
# (51, 10)

# %%
st_data_2009.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     88
# High-technology exports (current US$)                   88
# Trademark applications, total                          108
# Trademark applications, direct resident                118
# Trademark applications, direct nonresident             118
# Patent applications, residents                         126
# Patent applications, nonresidents                      118
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        122
# dtype: int64

# %%
st_data_2009.clean = st_data_2009.dropna()
st_data_2009.clean.shape
# Out:
# (56, 10)

# %% [markdown]
# ## Exploratoy

# %% [markdown]
# ### Descriptive Statistics

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
st_data_2018.clean.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bd5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bd5a_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_5bd5a_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_5bd5a_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_5bd5a_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_5bd5a_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_5bd5a_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_5bd5a_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.boxplot(x=st_data_2018.clean['High-technology exports (% of manufactured exports)'])
# Out:
# <Axes: xlabel='High-technology exports (% of manufactured exports)'>

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
st_data_2009.clean.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_090dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_090dc_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_090dc_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_090dc_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_090dc_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_090dc_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_090dc_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_090dc_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.boxplot(x=st_data_2009.clean['High-technology exports (% of manufactured exports)'])
# Out:
# <Axes: xlabel='High-technology exports (% of manufactured exports)'>

# %% [markdown]
# ## Outliers

# %%
columns = st_data_2018.clean.columns


for i in range(1,len(columns)):
   fig = plt.figure(figsize=(10,5))
   sns.boxplot(x=st_data_2018.clean[columns[i]])

# %%
article_max = st_data_2018.clean['Scientific and technical journal articles'].max()

# %%
st_data_2018.clean[st_data_2018.clean['Scientific and technical journal articles'] == article_max]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                              18.90
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                        156365524736.00                      464786.00
#
#      Trademark applications, direct resident  \
# 207                                342150.00
#
#      Trademark applications, direct nonresident  \
# 207                                   122636.00
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                       285095.00                          312046.00
#
#      Scientific and technical journal articles  \
# 207                                  422807.71
#
#      Research and development expenditure (% of GDP)
# 207                                             2.84

# %%
st_data_2018.clean[st_data_2018.clean['Scientific and technical journal articles'] > 60000]
# Out:
#            Country Name  High-technology exports (% of manufactured exports)  \
# 68               France                                              25.92
# 73              Germany                                              15.78
# 89                India                                               9.01
# 96                Italy                                               7.51
# 98                Japan                                              17.27
# 104         Korea, Rep.                                              36.35
# 161  Russian Federation                                              10.96
# 206      United Kingdom                                              22.64
# 207       United States                                              18.90
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 68                         117814412441.00                       98279.00
# ...

# %%
columns = st_data_2009.clean.columns


for i in range(1,len(columns)):
   fig = plt.figure(figsize=(10,5))
   sns.boxplot(x=st_data_2009.clean[columns[i]])

# %%
article_max = st_data_2009.clean['Scientific and technical journal articles'].max()

# %%
st_data_2009.clean[st_data_2009.clean['Scientific and technical journal articles'] == article_max]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                              25.01
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                        154108484413.00                      265943.00
#
#      Trademark applications, direct resident  \
# 207                                225045.00
#
#      Trademark applications, direct nonresident  \
# 207                                    40898.00
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                       224912.00                          231194.00
#
#      Scientific and technical journal articles  \
# 207                                  399350.31
#
#      Research and development expenditure (% of GDP)
# 207                                             2.81

# %%
st_data_2009.clean[st_data_2009.clean['Scientific and technical journal articles'] > 60000]
# Out:
#        Country Name  High-technology exports (% of manufactured exports)  \
# 41            China                                              31.95
# 68           France                                              24.38
# 73          Germany                                              16.88
# 98            Japan                                              20.59
# 178      South Asia                                               8.31
# 206  United Kingdom                                              20.80
# 207   United States                                              25.01
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 41                         359273932009.00                      806906.00
# 68                          88872522741.00                       83901.00
# 73                         159207939862.00                       74370.00
# 98                         104428943952.00                      109614.00
# ...

# %% [markdown]
# ## Exploring Relationship

# %% [markdown]
# ### Correlation

# %%
st_data_2018.clean.drop(columns=['Country Name']).corr(method= 'pearson').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_f415d_row0_col0, #T_f415d_row1_col1, #T_f415d_row2_col2, #T_f415d_row3_col3, #T_f415d_row4_col4, #T_f415d_row5_col5, #T_f415d_row6_col6, #T_f415d_row7_col7, #T_f415d_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f415d_row0_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_f415d_row0_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_f415d_row0_col3, #T_f415d_row8_col1, #T_f415d_row8_col6 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_f415d_row0_col4, #T_f415d_row8_col7 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_f415d_row0_col5, #T_f415d_row0_col6, #T_f415d_row0_col7, #T_f415d_row4_col8, #T_f415d_row6_col0, #T_f415d_row6_col1, #T_f415d_row8_col2, #T_f415d_row8_col3, #T_f415d_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_f415d_row0_col8 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_f415d_row1_col0 {
# ...

# %%
st_data_2018.clean.drop(columns=['Country Name']).corr(method= 'spearman').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_1aded_row0_col0, #T_1aded_row1_col1, #T_1aded_row2_col2, #T_1aded_row3_col3, #T_1aded_row4_col4, #T_1aded_row5_col5, #T_1aded_row6_col6, #T_1aded_row7_col7, #T_1aded_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_1aded_row0_col1, #T_1aded_row8_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_1aded_row0_col2 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_1aded_row0_col3 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_1aded_row0_col4 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_1aded_row0_col5, #T_1aded_row0_col6, #T_1aded_row0_col7, #T_1aded_row4_col0, #T_1aded_row4_col1, #T_1aded_row4_col8, #T_1aded_row8_col2, #T_1aded_row8_col3, #T_1aded_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1aded_row0_col8, #T_1aded_row7_col6 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_1aded_row1_col0, #T_1aded_row2_col5 {
# ...

# %%
st_data_2018.clean.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2018_nonUS = st_data_2018.clean[st_data_2018.clean['Country Name'] != 'United States']

# %%
st_data_2018_nonUS.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2009.clean.drop(columns=['Country Name']).corr(method= 'pearson').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_0947c_row0_col0, #T_0947c_row1_col1, #T_0947c_row2_col2, #T_0947c_row2_col3, #T_0947c_row3_col2, #T_0947c_row3_col3, #T_0947c_row4_col4, #T_0947c_row5_col5, #T_0947c_row6_col6, #T_0947c_row7_col7, #T_0947c_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_0947c_row0_col1 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_0947c_row0_col2 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_0947c_row0_col3 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_0947c_row0_col4 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_0947c_row0_col5, #T_0947c_row0_col6, #T_0947c_row0_col7, #T_0947c_row3_col0, #T_0947c_row3_col8, #T_0947c_row8_col1, #T_0947c_row8_col2, #T_0947c_row8_col3, #T_0947c_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_0947c_row0_col8, #T_0947c_row1_col0 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_0947c_row1_col2, #T_0947c_row3_col4 {
# ...

# %%
st_data_2009.clean.drop(columns=['Country Name']).corr(method= 'spearman').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_9ce08_row0_col0, #T_9ce08_row1_col1, #T_9ce08_row2_col2, #T_9ce08_row3_col3, #T_9ce08_row4_col4, #T_9ce08_row5_col5, #T_9ce08_row6_col6, #T_9ce08_row7_col7, #T_9ce08_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9ce08_row0_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_9ce08_row0_col2, #T_9ce08_row0_col3, #T_9ce08_row0_col5, #T_9ce08_row0_col7, #T_9ce08_row3_col0, #T_9ce08_row4_col1, #T_9ce08_row4_col8, #T_9ce08_row8_col4, #T_9ce08_row8_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_9ce08_row0_col4 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_9ce08_row0_col6 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_9ce08_row0_col8 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_9ce08_row1_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_9ce08_row1_col2 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_9ce08_row1_col3 {
# ...

# %%
st_data_2009.clean.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2009_nonUS = st_data_2009.clean[st_data_2009.clean['Country Name'] != 'United States']
st_data_2009_nonUS.plot.scatter(x='High-technology exports (% of manufactured exports)', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='High-technology exports (% of manufactured exports)', ylabel='Patent applications, nonresidents'>

# %% [markdown]
# # T-test

# %%
import scipy.stats as stats

# %%
import scipy.stats as stats
a = st_data_2009.clean['Patent applications, residents']
b = st_data_2018.clean['Patent applications, residents']
stats.ttest_ind(a,b)
# Out:
# TtestResult(statistic=np.float64(0.17093628150351461), pvalue=np.float64(0.8646028361752646), df=np.float64(105.0))

# %%
for i in range(1,len(columns)):
 a = st_data_2009.clean[columns[i]]
 b = st_data_2018.clean[columns[i]]
 print(columns[i])
 statistics, pvalue = stats.ttest_ind(a,b)
 print("Statistic: %s pvalue: %s" %(statistics, pvalue))
 if pvalue < 0.05:
   print("Reject null hypothesis")
 else:
   print("Fail to reject null hypothesis")
# Out:
# High-technology exports (% of manufactured exports)
# Statistic: 1.5178124850425097 pvalue: 0.13206686889029143
# Fail to reject null hypothesis
# High-technology exports (current US$)
# Statistic: 0.12265583290103693 pvalue: 0.902614099731734
# Fail to reject null hypothesis
# Trademark applications, total
# Statistic: 0.2704033385824462 pvalue: 0.7873807591420726
# Fail to reject null hypothesis
# Trademark applications, direct resident
# Statistic: 0.38774421679415133 pvalue: 0.6989902537733603
# Fail to reject null hypothesis
# Trademark applications, direct nonresident
# Statistic: -0.48589263440463604 pvalue: 0.628055750890876
# Fail to reject null hypothesis
# Patent applications, residents
# Statistic: 0.17093628150351461 pvalue: 0.8646028361752646
# Fail to reject null hypothesis
# Patent applications, nonresidents
# Statistic: -0.04471790792368344 pvalue: 0.9644170934929569
# Fail to reject null hypothesis
# Scientific and technical journal articles
# ...
