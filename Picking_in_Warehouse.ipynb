# %% [markdown]
# <a href="https://colab.research.google.com/github/Nanghomnoonaye/CGM-Telemonitoring/blob/main/Picking_in_Warehouse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # M6-V7 Exercise - picking

# %% [markdown]
# work at a warehouse ​where several items are collected to complete an order.

# %%
# Y = Picking time for picking all items in an order
# X = no. of item per order

# want to complete order b4 16:00.

Q: What time should employee start picking at the latest?

# %%
# Y, X (numerical)

# %% [markdown]
# ### prediction interval

# %% [markdown]
# ![Screenshot 2026-09-24 at 8.07.21 pm.png](data:image/png;base64,...)

# %%
Each additional item we picked takes an employee half a minute extra.

# %% [markdown]
# ![Screenshot 2026-09-24 at 8.09.33 pm.png](data:image/png;base64,...)

# %%
# 95% of the measurements will be within this prediction interval.

# 97.5% of the measurements ​will be below the upper boundary of the prediction interval.

# %%
Stats > Regression > Fitted Line Plots > option > predict

# %% [markdown]
# ![Screenshot 2026-09-24 at 8.13.25 pm.png](data:image/png;base64,...)

# %%
# So to pick 25 items, it will take me on average 17 minutes.

# to be sure to be done on time,
# ->you have to take 21 minutes in your planning because then ​you will always be done in 97.5% of the cases at least. ​

# %% [markdown]
# So in order to answer my question, ​you have performed a regression analysis and studied the prediction interval. ​You concluded that in 97.5% of the cases, the maximum time for ​completing an order of 25 items is 20.7 minutes. ​If you want to be done before 16.00hr, ​you have to start picking no later than 15.39hr.
